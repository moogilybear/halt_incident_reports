# %%
"""
This is a jupyter notebook for the QA and for data description. 

Before coming here, run the python files in the following order:
    1. n1_geturls.py
    2. n2_downloadfiles.py
    3. n3_scrapepdfs.py
    4. n4_cleandata.py
    
"""
# Out:
# '\nThis is a jupyter notebook for the QA and for data description. \n\nBefore coming here, run the python files in the following order:\n    1. n1_geturls.py\n    2. n2_downloadfiles.py\n    3. n3_scrapepdfs.py\n    4. n4_cleandata.py\n    \n'

# %%
#import packages
import pandas as pd
import numpy as np
import os
import datetime
import glob
import re
import datetime
import calendar
import matplotlib.pyplot as plt

#define directories
uncleaned_dir = "Halt Project/data/uncleaned/"
data_dir="Halt Project/data/"

# %% [markdown]
# # QA

# %%
#import dataframes from files

dfs = {}

# iterate over all files in the folder to create a dictionary of dataframes
for filename in os.listdir(uncleaned_dir):
    if filename.endswith('.csv'):  # check if the file is a csv
        filepath = os.path.join(uncleaned_dir, filename)  # get the full path to the file
        dataframe = pd.read_csv(filepath)  # import the csv as a dataframe
        name = os.path.splitext(filename)[0]  # remove the .csv extension from the filename
        dataframe.columns = [f'c{i+1}' for i in range(len(dataframe.columns))] # name columns c1 to c13
        dfs[name] = dataframe  # add the dataframe to the dictionary with the modified filename as the key

# create dataframes with custom names based on the dictionary keys
for name, dataframe in dfs.items():
    globals()[f"{name}"] = dataframe
    
#import final for QA as dataframe
final=pd.read_csv('Halt Project/data/final.csv')

# %%
dfs
# Out:
# {'december_2022':              c1    c2          c3  \
#  0           NaN   NaN         NaN
#  1          Date  Time    Facility
#  2    2022-12-01   900      Albion
#  3    2022-12-01  1530      Albion
#  4    2022-12-01   920      Auburn
#  ..          ...   ...         ...
#  670  2022-12-27  1855     Upstate
#  671  2022-12-27  2110     Upstate
#  672  2022-12-28  2000      Auburn
#  673  2022-12-28  1920  Gouverneur
#  674  2022-12-29   915     Collins
#
#                                                      c4    c5  \
#  0    Disciplinary Incidents Originally Resulting in...   NaN
#  1    TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...   NaN
#  2    3 102.10 THREATS 104.11 VIOLENT CONDUCT 106.10...  11.0
#  3    3 118.22 UNHYGIENIC ACT 102.10 THREATS 104.13 ...   3.0
#  4                                    3 113.10 WEAPON 1   1.0
#  ..                                                 ...   ...
#  670  3 114.10 SMUGGLING 113.19 EXCESS TOBACCO 113.2...   3.0
#  671                                3 100.13 FIGHTING 4   1.0
#  672  3 113.10 WEAPON 114.10 SMUGGLING 115.10 SEARCH...   5.0
#  673  3 102.10 THREATS 106.10 DIRECT ORDER 109.15 RE...   4.0
#  674  3 106.10 DIRECT ORDER 118.33 FLOODING 107.10 I...   3.0
#
#                      c6
#  0                  NaN
#  1    Original SHU Days
#  2                   90
#  3                   30
#  4                  180
#  ..                 ...
#  670                 33
#  671                 30
#  672                 90
#  673                 15
#  674                  1
#
#  [675 rows x 6 columns],
#  'september_2022':              c1            c2        c3  \
#  0           NaN           NaN       NaN
#  1          Date          Time  Facility
#  2    2022-09-01          1305    Attica
#  3    2022-09-01          1100    Auburn
#  4    2022-09-01          1250    Auburn
#  ..          ...           ...       ...
#  705        1605   Five Points         3
#  706         735  Great Meadow         3
#  707         710     Sing Sing         3
#  708        1215        Ulster         3
#  709        1520    Washington         3
#
#                                                      c4      c5  \
#  0    Disciplinary Incidents Originally Resulting in...     NaN
#  1    TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...     NaN
#  2    3 118.22 UNHYGIENIC ACT 102.10 THREATS 107.10 ...     3.0
#  3           3 101.20 LEWD CONDUCT 112.20 DELAY COUNT 2     2.0
#  4    3 113.10 WEAPON 115.10 SEARCH/FRISK 113.23 CON...     3.0
#  ..                                                 ...     ...
#  705                                         2022-09-28  106.10
#  706                                         2022-09-28  106.10
#  707                                         2022-09-28  100.11
#  708                                         2022-09-28  104.11
#  709                                         2022-09-28  100.11
#
#                      c6      c7               c8      c9               c10  \
#  0                  NaN     NaN              NaN     NaN               NaN
#  1    Original SHU Days     NaN              NaN     NaN               NaN
#  2                   89     NaN              NaN     NaN               NaN
#  3                   60     NaN              NaN     NaN               NaN
#  4                   90     NaN              NaN     NaN               NaN
#  ..                 ...     ...              ...     ...               ...
#  705       DIRECT ORDER  107.10     INTERFERENCE  116.10  LOSS/DAMAGE PROP
#  706       DIRECT ORDER  104.13   CREATE DISTURB     NaN               NaN
#  707   ASSAULT ON STAFF  104.11  VIOLENT CONDUCT  112.22    OBSTRUCT VISIB
#  708    VIOLENT CONDUCT  106.10     DIRECT ORDER  118.21   FLAMMABLE MATER
#  709   ASSAULT ON STAFF  104.11  VIOLENT CONDUCT  115.10      SEARCH/FRISK
#
#       c11  c12  c13
#  0    NaN  NaN  NaN
#  1    NaN  NaN  NaN
#  2    NaN  NaN  NaN
#  3    NaN  NaN  NaN
#  4    NaN  NaN  NaN
#  ..   ...  ...  ...
#  705    4    4   60
#  706    5    2    2
#  707    3    3  120
#  708    4    4   10
#  709    4    4   59
#
#  [710 rows x 13 columns],
#  'november_2022':              c1    c2          c3  \
#  0           NaN   NaN         NaN
#  1          Date  Time    Facility
#  2    2022-11-01  1320      Albion
#  3    2022-11-01  1320      Auburn
#  4    2022-11-01  1320      Auburn
#  ..          ...   ...         ...
#  676  2022-11-29   835  Washington
#  677  2022-11-30  1335      Auburn
#  678  2022-11-30  1345      Cayuga
#  679  2022-11-30   755      Mohawk
#  680  2022-11-30  1455     Wyoming
#
#                                                      c4   c5                 c6
#  0    Disciplinary Incidents Originally Resulting in...  NaN                NaN
#  1    TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...  NaN  Original SHU Days
#  2         3 113.23 CONTRABAND 113.22 PROP UNAUTH LOC 3  2.0                 10
#  3    3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...  4.0                 90
#  4    3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 104.1...  3.0                 30
#  ..                                                 ...  ...                ...
#  676  3 100.10 ASSAULT ON INCAR INDIV 100.13 FIGHTIN...  4.0                 42
#  677                 3 113.10 WEAPON 114.10 SMUGGLING 2  2.0                179
#  678  3 100.11 ASSAULT ON STAFF 104.11 VIOLENT CONDU...  6.0                 32
#  679                3 113.10 WEAPON 113.23 CONTRABAND 2  2.0                119
#  680  3 100.10 ASSAULT ON INCAR INDIV 113.10 WEAPON ...  3.0                122
#
#  [681 rows x 6 columns],
#  'july_2022':              c1         c2        c3  \
#  0           NaN        NaN       NaN
#  1          Date       Time  Facility
#  2    2022-07-01       1830    Albion
#  3    2022-07-01       1830    Albion
#  4    2022-07-01       2130    Auburn
#  ..          ...        ...       ...
#  803        1100      Marcy         3
#  804         548  Bare Hill         3
#  805        1443    Clinton         3
#  806        1335     Elmira         3
#  807           5   Franklin         3
#
#                                                      c4      c5  \
#  0    Disciplinary Incidents Originally Resulting in...     NaN
#  1    TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...     NaN
#  2    3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 107.1...     4.0
#  3    3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 107.1...     4.0
#  4    3 104.12 DEMONSTRATION 106.10 DIRECT ORDER 107...     4.0
#  ..                                                 ...     ...
#  803                                         2022-07-26  100.11
#  804                                         2022-07-27  102.10
#  805                                         2022-07-27  100.10
#  806                                         2022-07-27  100.10
#  807                                         2022-07-28  102.10
#
#                           c6      c7                c8      c9  \
#  0                       NaN     NaN               NaN     NaN
#  1         Original SHU Days     NaN               NaN     NaN
#  2                        60     NaN               NaN     NaN
#  3                        45     NaN               NaN     NaN
#  4                       180     NaN               NaN     NaN
#  ..                      ...     ...               ...     ...
#  803        ASSAULT ON STAFF  100.11  ASSAULT ON STAFF  104.11
#  804                 THREATS  106.10      DIRECT ORDER  107.10
#  805  ASSAULT ON INCAR INDIV  113.10            WEAPON  100.13
#  806  ASSAULT ON INCAR INDIV  113.10            WEAPON  100.13
#  807                 THREATS  106.10      DIRECT ORDER     NaN
#
#                   c10  c11  c12  c13
#  0                NaN  NaN  NaN  NaN
#  1                NaN  NaN  NaN  NaN
#  2                NaN  NaN  NaN  NaN
#  3                NaN  NaN  NaN  NaN
#  4                NaN  NaN  NaN  NaN
#  ..               ...  ...  ...  ...
#  803  VIOLENT CONDUCT    5    4  180
#  804     INTERFERENCE    6    5   60
#  805         FIGHTING    6    6  250
#  806         FIGHTING    5    5  180
#  807              NaN    3    2   17
#
#  [808 rows x 13 columns],
#  'june_2022':              c1                c2   c3  \
#  0           NaN               NaN  NaN
#  1          Date     Time Facility  NaN
#  2    2022-06-01        905 Albion  NaN
#  3    2022-06-01       1010 Albion  NaN
#  4    2022-06-01        905 Albion  NaN
#  ..          ...               ...  ...
#  716  2022-06-22  1405 Five Points  NaN
#  717  2022-06-22       2300 Greene  NaN
#  718  2022-06-22        830 Mohawk  NaN
#  719  2022-06-22       915 Upstate  NaN
#  720  2022-06-22         830 Wende  NaN
#
#                                                      c4   c5                 c6
#  0    Disciplinary Incidents Originally Resulting in...  NaN                NaN
#  1    TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...  NaN  Original SHU Days
#  2    3 118.22 UNHYGIENIC ACT 104.11 VIOLENT CONDUCT...  4.0                 14
#  3    3 104.11 VIOLENT CONDUCT 106.10 DIRECT ORDER 1...  4.0                 90
#  4    3 102.10 THREATS 104.11 VIOLENT CONDUCT 104.13...  3.0                 30
#  ..                                                 ...  ...                ...
#  716  3 100.10 ASSAULT ON INCAR INDIV 113.10 WEAPON ...  6.0                271
#  717  3 102.10 THREATS 106.10 DIRECT ORDER 107.10 IN...  4.0                 30
#  718  3 100.11 ASSAULT ON STAFF 104.11 VIOLENT CONDU...  3.0                270
#  719        3 106.10 DIRECT ORDER 107.10 INTERFERENCE 2  2.0                 60
#  720  3 104.11 VIOLENT CONDUCT 104.12 DEMONSTRATION ...  6.0                240
#
#  [721 rows x 6 columns],
#  'concatenated_data':               c1        c2        c3  \
#  0            NaN       NaN       NaN
#  1           Date      Time  Facility
#  2     2022-09-01      1305    Attica
#  3     2022-09-01      1100    Auburn
#  4     2022-09-01      1250    Auburn
#  ...          ...       ...       ...
#  7856        Days       NaN       NaN
#  7857        1145  Wallkill         3
#  7858        0820   Clinton         3
#  7859        0800   Collins         3
#  7860        0905    Greene         3
#
#                                                       c4      c5  \
#  0     Disciplinary Incidents Originally Resulting in...     NaN
#  1     TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...     NaN
#  2     3 118.22 UNHYGIENIC ACT 102.10 THREATS 107.10 ...     3.0
#  3            3 101.20 LEWD CONDUCT 112.20 DELAY COUNT 2     2.0
#  4     3 113.10 WEAPON 115.10 SEARCH/FRISK 113.23 CON...     3.0
#  ...                                                 ...     ...
#  7856                                                NaN     NaN
#  7857                                         2022-04-27  100.10
#  7858                                         2022-04-28  104.11
#  7859                                         2022-04-28  106.10
#  7860                                         2022-04-28  113.10
#
#                       c6      c7            c8      c9              c10  c11  \
#  0                   NaN     NaN           NaN     NaN              NaN  NaN
#  1     Original SHU Days     NaN           NaN     NaN              NaN  NaN
#  2                    89     NaN           NaN     NaN              NaN  NaN
#  3                    60     NaN           NaN     NaN              NaN  NaN
#  4                    90     NaN           NaN     NaN              NaN  NaN
#  ...                 ...     ...           ...     ...              ...  ...
#  7856                NaN     NaN           NaN     NaN              NaN  NaN
#  7857  ASSAULT ON INMATE  113.10        WEAPON  104.11  VIOLENT CONDUCT    4
#  7858    VIOLENT CONDUCT  115.10  SEARCH/FRISK  106.10     DIRECT ORDER    5
#  7859       DIRECT ORDER  107.10  INTERFERENCE  109.12     MOVEMENT VIO    3
#  7860             WEAPON  113.23    CONTRABAND  113.11     ALTERED ITEM    3
#
#        c12  c13
#  0     NaN  NaN
#  1     NaN  NaN
#  2     NaN  NaN
#  3     NaN  NaN
#  4     NaN  NaN
#  ...   ...  ...
#  7856  NaN  NaN
#  7857    4  177
#  7858    3   45
#  7859    3   59
#  7860    3   35
#
#  [7861 rows x 13 columns],
#  'may_2022':               c1          c2        c3  \
#  0            NaN         NaN       NaN
#  1           Date        Time  Facility
#  2     2022-05-01        2055    Attica
#  3     2022-05-01        1627    Attica
#  4     2022-05-01        1105    Attica
#  ...          ...         ...       ...
#  1111        2240       Marcy         3
#  1112         655      Mohawk         3
#  1113        1148    Sullivan         3
#  1114        2200    Sullivan         3
#  1115        1515  Washington         3
#
#                                                       c4      c5  \
#  0     Disciplinary Incidents Originally Resulting in...     NaN
#  1     TIER Guilty1 Guilty2 Guilty3 Total Infractions...     NaN
#  2     3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...     4.0
#  3     3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...     5.0
#  4     3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...     5.0
#  ...                                                 ...     ...
#  1111                                         2022-05-31  100.13
#  1112                                         2022-05-31  100.13
#  1113                                         2022-05-31  113.10
#  1114                                         2022-05-31  105.13
#  1115                                         2022-05-31  102.10
#
#                       c6      c7                c8      c9           c10  c11  \
#  0                   NaN     NaN               NaN     NaN           NaN  NaN
#  1     Original SHU Days     NaN               NaN     NaN           NaN  NaN
#  2                   114     NaN               NaN     NaN           NaN  NaN
#  3                   180     NaN               NaN     NaN           NaN  NaN
#  4                    89     NaN               NaN     NaN           NaN  NaN
#  ...                 ...     ...               ...     ...           ...  ...
#  1111           FIGHTING  104.11   VIOLENT CONDUCT  106.10  DIRECT ORDER    3
#  1112           FIGHTING  104.11   VIOLENT CONDUCT  106.10  DIRECT ORDER    4
#  1113             WEAPON  106.10      DIRECT ORDER  107.10  INTERFERENCE    6
#  1114              GANGS  116.10  LOSS/DAMAGE PROP     NaN           NaN    2
#  1115            THREATS  106.10      DIRECT ORDER  107.10  INTERFERENCE    5
#
#        c12  c13
#  0     NaN  NaN
#  1     NaN  NaN
#  2     NaN  NaN
#  3     NaN  NaN
#  4     NaN  NaN
#  ...   ...  ...
#  1111    3   62
#  1112    4   77
#  1113    6  120
#  1114    2   60
#  1115    5   90
#
#  [1116 rows x 13 columns],
#  'august_2022':              c1           c2        c3  \
#  0           NaN          NaN       NaN
#  1          Date         Time  Facility
#  2    2022-08-01         1328    Attica
#  3    2022-08-01         1328    Attica
#  4    2022-08-01         1040    Attica
#  ..          ...          ...       ...
#  784         NaN          NaN       NaN
#  785        Time     Facility      TIER
#  786        1235      Wyoming         3
#  787         200     Franklin         3
#  788         915  Green Haven         3
#
#                                                      c4       c5  \
#  0    Disciplinary Incidents Originally Resulting in...      NaN
#  1    TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...      NaN
#  2    3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...      5.0
#  3    3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...      5.0
#  4    3 113.10 WEAPON 113.23 CONTRABAND 113.11 ALTER...      3.0
#  ..                                                 ...      ...
#  784  Disciplinary Incidents Originally Resulting in...      NaN
#  785                                               Date  Guilty1
#  786                                         2022-08-24   113.10
#  787                                         2022-08-25   102.10
#  788                                         2022-08-25   100.10
#
#                           c6       c7            c8       c9              c10  \
#  0                       NaN      NaN           NaN      NaN              NaN
#  1         Original SHU Days      NaN           NaN      NaN              NaN
#  2                       119      NaN           NaN      NaN              NaN
#  3                        90      NaN           NaN      NaN              NaN
#  4                        89      NaN           NaN      NaN              NaN
#  ..                      ...      ...           ...      ...              ...
#  784                     NaN      NaN           NaN      NaN              NaN
#  785                 G1Label  Guilty2       G2Label  Guilty3          G3Label
#  786                  WEAPON   100.13      FIGHTING   104.11  VIOLENT CONDUCT
#  787                 THREATS   106.10  DIRECT ORDER      NaN              NaN
#  788  ASSAULT ON INCAR INDIV   113.10        WEAPON   100.13         FIGHTING
#
#                     c11                       c12                c13
#  0                  NaN                       NaN                NaN
#  1                  NaN                       NaN                NaN
#  2                  NaN                       NaN                NaN
#  3                  NaN                       NaN                NaN
#  4                  NaN                       NaN                NaN
#  ..                 ...                       ...                ...
#  784                NaN                       NaN                NaN
#  785  Total Infractions  Total Guilty Infractions  Original SHU Days
#  786                  6                         6                121
#  787                  3                         2                101
#  788                  6                         4                135
#
#  [789 rows x 13 columns],
#  'october_2022':              c1    c2             c3  \
#  0           NaN   NaN            NaN
#  1          Date  Time       Facility
#  2    2022-10-01  1150         Attica
#  3    2022-10-01  1150         Attica
#  4    2022-10-01  1005  Bedford Hills
#  ..          ...   ...            ...
#  682  2022-10-25  1135     Woodbourne
#  683  2022-10-26    25         Attica
#  684  2022-10-26  1625        Clinton
#  685  2022-10-26  1625        Clinton
#  686  2022-10-26   845       Franklin
#
#                                                      c4    c5  \
#  0    Disciplinary Incidents Originally Resulting in...   NaN
#  1    TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...   NaN
#  2    3 100.10 ASSAULT ON INCAR INDIV 100.13 FIGHTIN...   4.0
#  3    3 100.10 ASSAULT ON INCAR INDIV 104.11 VIOLENT...   5.0
#  4    3 100.11 ASSAULT ON STAFF 118.22 UNHYGIENIC AC...   9.0
#  ..                                                 ...   ...
#  682  3 100.10 ASSAULT ON INCAR INDIV 100.11 ASSAULT...  11.0
#  683  3 102.10 THREATS 106.10 DIRECT ORDER 104.13 CR...   5.0
#  684  3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...   4.0
#  685  3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...   4.0
#  686  3 102.10 THREATS 106.10 DIRECT ORDER 107.20 FA...   4.0
#
#                      c6
#  0                  NaN
#  1    Original SHU Days
#  2                   45
#  3                   45
#  4                  160
#  ..                 ...
#  682                 90
#  683                 89
#  684                 60
#  685                 30
#  686                 60
#
#  [687 rows x 6 columns],
#  'january_2023':              c1           c2             c3  \
#  0           NaN          NaN            NaN
#  1          Date         Time       Facility
#  2    2023-01-01          830         Auburn
#  3    2023-01-01          830         Auburn
#  4    2023-01-01         1250  Bedford Hills
#  ..          ...          ...            ...
#  679         800  Five Points              3
#  680        1350       Elmira              3
#  681        1145     Franklin              3
#  682        1145     Franklin              3
#  683        1500    Riverview              3
#
#                                                      c4      c5  \
#  0    Disciplinary Incidents Originally Resulting in...     NaN
#  1    TIER Guilty1 G1Label Guilty2 G2Label Guilty3 G...     NaN
#  2    3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...     3.0
#  3    3 100.13 FIGHTING 104.11 VIOLENT CONDUCT 106.1...     4.0
#  4    3 102.10 THREATS 106.10 DIRECT ORDER 107.10 IN...     4.0
#  ..                                                 ...     ...
#  679                                         2023-01-24  100.13
#  680                                         2023-01-25  100.10
#  681                                         2023-01-25  100.13
#  682                                         2023-01-25  100.13
#  683                                         2023-01-25  102.10
#
#                           c6      c7               c8      c9              c10  \
#  0                       NaN     NaN              NaN     NaN              NaN
#  1         Original SHU Days     NaN              NaN     NaN              NaN
#  2                        30     NaN              NaN     NaN              NaN
#  3                        90     NaN              NaN     NaN              NaN
#  4                        30     NaN              NaN     NaN              NaN
#  ..                      ...     ...              ...     ...              ...
#  679                FIGHTING  104.11  VIOLENT CONDUCT  106.10     DIRECT ORDER
#  680  ASSAULT ON INCAR INDIV  100.13         FIGHTING  104.11  VIOLENT CONDUCT
#  681                FIGHTING  104.11  VIOLENT CONDUCT  106.10     DIRECT ORDER
#  682                FIGHTING  104.11  VIOLENT CONDUCT  106.10     DIRECT ORDER
#  683                 THREATS  104.11  VIOLENT CONDUCT     NaN              NaN
#
#       c11  c12  c13
#  0    NaN  NaN  NaN
#  1    NaN  NaN  NaN
#  2    NaN  NaN  NaN
#  3    NaN  NaN  NaN
#  4    NaN  NaN  NaN
#  ..   ...  ...  ...
#  679    4    4   30
#  680    5    5   90
#  681    3    3   30
#  682    3    3   90
#  683    3    2   40
#
#  [684 rows x 13 columns],
#  'april_2022':                                                     c1            c2  \
#  0    Incidents Originally Resulting in a SHU sancti...           NaN
#  1                                                 Date          Time
#  2                                          Infractions  Total Guilty
#  3                                          Infractions      Original
#  4                                                  SHU           NaN
#  ..                                                 ...           ...
#  985                                               Days           NaN
#  986                                         2022-04-27          1145
#  987                                         2022-04-28          0820
#  988                                         2022-04-28          0800
#  989                                         2022-04-28          0905
#
#             c3    c4       c5                 c6       c7            c8  \
#  0         NaN   NaN      NaN                NaN      NaN           NaN
#  1    Facility  TIER  Guilty1                NaN  Guilty2           NaN
#  2         NaN   NaN      NaN                NaN      NaN           NaN
#  3         NaN   NaN      NaN                NaN      NaN           NaN
#  4         NaN   NaN      NaN                NaN      NaN           NaN
#  ..        ...   ...      ...                ...      ...           ...
#  985       NaN   NaN      NaN                NaN      NaN           NaN
#  986  Wallkill     3   100.10  ASSAULT ON INMATE   113.10        WEAPON
#  987   Clinton     3   104.11    VIOLENT CONDUCT   115.10  SEARCH/FRISK
#  988   Collins     3   106.10       DIRECT ORDER   107.10  INTERFERENCE
#  989    Greene     3   113.10             WEAPON   113.23    CONTRABAND
#
#            c9              c10    c11  c12    c13
#  0        NaN              NaN    NaN  NaN    NaN
#  1    Guilty3              NaN  Total  NaN    NaN
#  2        NaN              NaN    NaN  NaN    NaN
#  3        NaN              NaN    NaN  NaN    NaN
#  4        NaN              NaN    NaN  NaN    NaN
#  ..       ...              ...    ...  ...    ...
#  985      NaN              NaN    NaN  NaN    NaN
#  986   104.11  VIOLENT CONDUCT      4  4.0  177.0
#  987   106.10     DIRECT ORDER      5  3.0   45.0
#  988   109.12     MOVEMENT VIO      3  3.0   59.0
#  989   113.11     ALTERED ITEM      3  3.0   35.0
#
#  [990 rows x 13 columns]}

# %%
#Check that the number of records per each month matches the number of records in the pdfs. 
#create a new column in the final dataframe which labels year_month. 
#group the final dataframe by year_monht
final['date'] = pd.to_datetime(final['date'])
final['year_month'] = final['date'].dt.strftime('%Y-%m')
numbymonth=final.groupby(['year_month']).size().reset_index()
numbymonth.columns=['year_month','numrows']
numbymonth['year_month_d']=pd.to_datetime(numbymonth['year_month'])
numbymonth['ym']=numbymonth['year_month_d'].dt.strftime('%B_%Y').str.lower()
                    
#create a dictioanry that maps the file to the number of pages in each report. 
import PyPDF2

pdf_page_counts={}
for filename in os.listdir(download_dir):
    if filename.endswith('.pdf'):
        file_date=re.search(r'(\w+-\d{4})\.pdf',filename).group(1)
        month,year=file_date.split('-')
        file_date=f"{month.lower()}_{year}"
        with open(os.path.join(download_dir,filename),'rb') as f:
            pdf_reader=PyPDF2.PdfFileReader(f)
            num_pages=pdf_reader.getNumPages()
            pdf_page_counts[file_date]=num_pages
            
#create a dictionary that shows the scraped dataframes and lengths
df_lengths={key:len(dfs[key]) for key in dfs}

#map the scraped dataframe lengths
numbymonth['dflen']=numbymonth['ym'].map(df_lengths)

#map the pdf page counts
numbymonth['pgcts']=numbymonth['ym'].map(pdf_page_counts)

#calculate the expected number of rows based on the page count and dataframe length. 
#the expected number of rows will be the (dataframe length)-2*the number of pages
#because each month except for april has two extra rows containing column information
#april for some reason has six extra imported rows, so you need to modify the formula
numbymonth['expected_rows'] = numbymonth['dflen'] - (numbymonth['pgcts'] * np.where(numbymonth['ym'] == 'april_2022', 6, 2))


#compare the expected rows and the actual number of rows:
numbymonth['numrows']=numbymonth['numrows'].astype(str)
numbymonth['expected_rows']=numbymonth['expected_rows'].astype(str).str.split('.').str[0]

for idx, row in numbymonth.iterrows():
    if row['expected_rows']==' ':
        print(f"Issue found with {row['ym']}")
    elif row['expected_rows']==(row['numrows']):
        print('Perfect Match!')
    else:
        print(f"Issue found with {row['ym']}")
# Out:
# Perfect Match!
# Perfect Match!
# Perfect Match!
# Perfect Match!
# Perfect Match!
# Perfect Match!
# Perfect Match!
# Perfect Match!
# Perfect Match!
# Perfect Match!

# %%
#Check that the total number of expected rows equals the total number of rows in the final dataframe
#this ensures there are no extra rows. 
expectedtotrows=numbymonth['numrows'].astype(int).sum()
actualtotrows=len(final)
if actualtotrows==expectedtotrows:
    print("Actual Total Rows = Expected Total Rows")
else:
    print('Actual Total Rows != Expected Total Rows')
# Out:
# Actual Total Rows = Expected Total Rows

# %%
#Let's check to make sure that all of the facilities are listed by cross-referencing another source.
#dataframe 'sec_level' (Security Level) was created by gathering information from 
#this map: https://doccs.ny.gov/system/files/documents/2022/09/facility-map-11-1-22.pdf

sec_level = [
            ['EDGECOMBE', 'MINIMUM','BRONX'], ['LAKEVIEW', 'MINIMUM','WESTERN'], ['QUEENSBORO', 'MINIMUM','QUEENS-LI'],
            ['ADIRONDACK', 'MEDIUM','CENTRAL'], ['ALBION', 'MEDIUM','WESTERN'], ['ALTONA', 'MEDIUM','CENTRAL'],
            ['BARE HILL', 'MEDIUM','CENTRAL'], ['CAPE VINCENT', 'MEDIUM','CENTRAL'], ['CAYUGA', 'MEDIUM','CENTRAL'],
            ['COLLINS', 'MEDIUM','WESTERN'], ['FISHKILL', 'MEDIUM','HUDSON VALLEY'], ['FRANKLIN', 'MEDIUM','CENTRAL'],
            ['GOUVERNEUR', 'MEDIUM','CENTRAL'], ['GREENE', 'MEDIUM','HUDSON VALLEY'], ['GROVELAND', 'MEDIUM','WESTERN'],
            ['HALE CREEK', 'MEDIUM','HUDSON VALLEY'], ['HUDSON', 'MEDIUM','HUDSON VALLEY'], ['MARCY', 'MEDIUM','CENTRAL'],
            ['MID-STATE', 'MEDIUM','CENTRAL'], ['MOHAWK', 'MEDIUM','CENTRAL'], ['ORLEANS', 'MEDIUM','WESTERN'],
            ['OTISVILLE', 'MEDIUM','HUDSON VALLEY'], ['RIVERVIEW', 'MEDIUM','CENTRAL'], ['TACONIC', 'MEDIUM','HUDSON VALLEY'],
            ['ULSTER', 'MEDIUM','HUDSON VALLEY'], ['WALLKILL', 'MEDIUM','HUDSON VALLEY'], ['WASHINGTON', 'MEDIUM','HUDSON VALLEY'],
            ['WOODBOURNE', 'MEDIUM','HUDSON VALLEY'], ['WYOMING', 'MEDIUM','WESTERN'],
            ['ATTICA', 'MAXIMUM','WESTERN'], ['AUBURN', 'MAXIMUM','CENTRAL'], ['BEDFORD HILLS', 'MAXIMUM','HUDSON VALLEY'],
            ['CLINTON', 'MAXIMUM','CENTRAL'], ['COXSACKIE', 'MAXIMUM','HUDSON VALLEY'], ['EASTERN', 'MAXIMUM','HUDSON VALLEY'],
            ['ELMIRA', 'MAXIMUM','CENTRAL'], ['FIVE POINTS', 'MAXIMUM','CENTRAL'], ['GREAT MEADOW', 'MAXIMUM','HUDSON VALLEY'],
            ['GREEN HAVEN', 'MAXIMUM','HUDSON VALLEY'], ['SHAWANGUNK', 'MAXIMUM','HUDSON VALLEY'], ['SING SING', 'MAXIMUM','HUDSON VALLEY'],
            ['SULLIVAN', 'MAXIMUM','HUDSON VALLEY'], ['UPSTATE', 'MAXIMUM','CENTRAL'], ['WENDE', 'MAXIMUM','WESTERN']
            ]

sec = pd.DataFrame(sec_level, columns=['facility','security_level','borough'])

# convert 'facility' column to lowercase for case-insensitivity
final['facility'] = final['facility'].str.lower()
sec['facility'] = sec['facility'].str.lower()

# find values in 'facility' column of alldata that are not in 'facility' column of sec
not_in_sec = final.loc[~final['facility'].isin(sec['facility'])]
print('there are',len(sec_level),'facilities in the sec_level dataframe.')
print('there are',final['facility'].nunique(),'facilities in the final dataframe.')
not_in_sec
# Out:
# there are 44 facilities in the sec_level dataframe.
# there are 45 facilities in the final dataframe.
#       time facility  tier       date      g1            g1_label      g2  \
# 1082  1215  uncoded     3 2022-12-15  100.11   ASSAULT ON STAFF   104.11
# 2197   830  uncoded     3 2023-01-04  118.22     UNHYGIENIC ACT   104.11
# 2264   830  uncoded     3 2023-01-06  113.10             WEAPON   114.10
# 2334   950  uncoded     3 2023-01-09  102.10            THREATS   107.10
# 2422  1715  uncoded     3 2023-01-11  111.11   POSSESS EMP PROP   102.10
# 2556  1223  uncoded     3 2023-01-16  118.10              ARSON   104.11
# 2634   830  uncoded     3 2023-01-19  100.11   ASSAULT ON STAFF   102.10
#
#                g2_label      g3           g3_label  tot_infractions  \
# 1082   VIOLENT CONDUCT      NaN                NaN                3
# 2197   VIOLENT CONDUCT   104.13    CREATE DISTURB                 3
# 2264         SMUGGLING      NaN                NaN                2
# 2334      INTERFERENCE   104.13    CREATE DISTURB                 3
# 2422           THREATS   106.10      DIRECT ORDER                 5
# 2556   VIOLENT CONDUCT   115.10      SEARCH/FRISK                 7
# 2634           THREATS   104.11   VIOLENT CONDUCT                11
#
#       tot_g_infractions  orig_shu_days year_month
# 1082                2.0             90    2022-12
# 2197                3.0             45    2023-01
# 2264                2.0            180    2023-01
# 2334                3.0             60    2023-01
# 2422                5.0             60    2023-01
# 2556                7.0             90    2023-01
# 2634               10.0            180    2023-01

# %% [markdown]
# # Part 5: Describe the Data

# %%
#Let's start by listing the uncoded facilities discovered during the QA.
uncoded=final[final['facility']=='uncoded']
print('There are',len(uncoded),'records which do not have a Facility coded for them.')

#download the csv
uncoded.to_csv(data_dir+'uncodedfacilityrecords.csv')
uncoded
# Out:
# There are 7 records which do not have a Facility coded for them.
#       time facility  tier       date      g1            g1_label      g2  \
# 1082  1215  uncoded     3 2022-12-15  100.11   ASSAULT ON STAFF   104.11
# 2197   830  uncoded     3 2023-01-04  118.22     UNHYGIENIC ACT   104.11
# 2264   830  uncoded     3 2023-01-06  113.10             WEAPON   114.10
# 2334   950  uncoded     3 2023-01-09  102.10            THREATS   107.10
# 2422  1715  uncoded     3 2023-01-11  111.11   POSSESS EMP PROP   102.10
# 2556  1223  uncoded     3 2023-01-16  118.10              ARSON   104.11
# 2634   830  uncoded     3 2023-01-19  100.11   ASSAULT ON STAFF   102.10
#
#                g2_label      g3           g3_label  tot_infractions  \
# 1082   VIOLENT CONDUCT      NaN                NaN                3
# 2197   VIOLENT CONDUCT   104.13    CREATE DISTURB                 3
# 2264         SMUGGLING      NaN                NaN                2
# 2334      INTERFERENCE   104.13    CREATE DISTURB                 3
# 2422           THREATS   106.10      DIRECT ORDER                 5
# 2556   VIOLENT CONDUCT   115.10      SEARCH/FRISK                 7
# 2634           THREATS   104.11   VIOLENT CONDUCT                11
#
#       tot_g_infractions  orig_shu_days year_month
# 1082                2.0             90    2022-12
# 2197                3.0             45    2023-01
# 2264                2.0            180    2023-01
# 2334                3.0             60    2023-01
# 2422                5.0             60    2023-01
# 2556                7.0             90    2023-01
# 2634               10.0            180    2023-01

# %%
#Let's look at descriptive statistics for each of the columns 
stats=final.describe(include='all',datetime_is_numeric=True)
stats.to_csv(data_dir+'stats.csv')
stats
# Out:
#                time facility    tier                           date  \
# count   7445.000000     7445  7445.0                           7445
# unique          NaN       45     NaN                            NaN
# top             NaN  upstate     NaN                            NaN
# freq            NaN      584     NaN                            NaN
# mean    1332.874681      NaN     3.0  2022-08-16 00:18:22.484889344
# min        0.000000      NaN     3.0            2022-04-01 00:00:00
# 25%      940.000000      NaN     3.0            2022-05-27 00:00:00
# 50%     1258.000000      NaN     3.0            2022-08-08 00:00:00
# 75%     1715.000000      NaN     3.0            2022-11-03 00:00:00
# max     2359.000000      NaN     3.0            2023-01-25 00:00:00
# std      474.997236      NaN     0.0                            NaN
#
#                  g1    g1_label           g2           g2_label           g3  \
# count   7445.000000        7445  6922.000000               6922  5769.000000
# unique          NaN          61          NaN                 98          NaN
# top             NaN   FIGHTING           NaN   VIOLENT CONDUCT           NaN
# freq            NaN        1361          NaN               2198          NaN
# mean     104.534109         NaN   107.360030                NaN   107.643923
# min      100.100000         NaN   100.100000                NaN   100.110000
# 25%      100.130000         NaN   104.110000                NaN   104.130000
# 50%      102.100000         NaN   104.130000                NaN   106.100000
# 75%      106.100000         NaN   113.100000                NaN   107.100000
# max      118.220000         NaN   181.100000                NaN   181.100000
# std        5.680273         NaN     7.394094                NaN     8.657347
#
#               g3_label  tot_infractions  tot_g_infractions  orig_shu_days  \
# count             5769      7445.000000        7445.000000    7445.000000
# unique             105              NaN                NaN            NaN
# top      DIRECT ORDER               NaN                NaN            NaN
# freq              1624              NaN                NaN            NaN
# mean               NaN         4.198925           3.789657     100.815581
# min                NaN         1.000000           1.000000       1.000000
# 25%                NaN         3.000000           3.000000      34.000000
# 50%                NaN         4.000000           4.000000      67.000000
# 75%                NaN         5.000000           5.000000     120.000000
# max                NaN        21.000000          19.000000    1825.000000
# std                NaN         1.916247           1.815385     102.159819
#
#        year_month
# count        7445
# unique         10
# top       2022-05
# freq         1068
# mean          NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
# std           NaN

# %%
#Let's look at how many unique guilty values there are. 
#Create a dictionary of all guilties by concatenating all guilty values into a single dataframe
g1df=final[['g1','g1_label']]
g2df=final[['g2','g2_label']]
g3df=final[['g3','g3_label']]
g1df.columns=['g','g_label']
g2df.columns=['g','g_label']
g3df.columns=['g','g_label']
gdf=pd.concat([g1df,g2df,g3df],axis=0)

#drop nas
gdf.dropna(how='all', inplace=True)

#format column
gdf['g']=gdf['g'].astype(str) 
gdf['g'] = gdf['g'].str.strip() #strip out white spaces
gdf['g_label'] = gdf['g_label'].str.strip() #strip out white spaces
gdf['g'] = gdf['g'].replace(r'^\s*$', np.nan, regex=True)
gdf['g'] = pd.to_numeric(gdf['g'], errors='coerce')
# Format values with two decimal places
gdf['g'] = gdf['g'].map(lambda x: f"{x:.2f}" if not np.isnan(x) else '')

#create dictionary
gdict=dict(zip(gdf['g'], gdf['g_label']))

#remove any empty dictionary entries
gdict = {k: v for k, v in gdict.items() if v != ''}

#print the number of guilty codes
print('there are',len(gdict),'guilty codes')

#download the guilty codes as a csv
gdict_df = pd.DataFrame.from_dict(gdict, orient='index')
gdict_df.to_csv(data_dir+'unique_guilty_values.csv')
# Out:
# there are 81 guilty codes

# %%
# Loop through each dictionary entry to create a boolean column for whether the guilty is in the row
# Create a new column in the dataframe for the current dictionary entry
# Set the value to True if the entry is present in g1, g2, or g3
for k, v in gdict.items():
    final[v] = final[['g1', 'g2', 'g3']].apply(lambda x: x.isin([k]).any(), axis=1)

#look at the grouped guilties
final[['g1', 'g2', 'g3']] = final[['g1', 'g2', 'g3']].astype(str)
final[['g1_label', 'g2_label', 'g3_label']] = final[['g1_label', 'g2_label', 'g3_label']].fillna('')
final['g']=final['g1']+'-'+final['g2']+'-'+final['g3']
final['g_label']=final['g1_label']+'-'+final['g2_label']+'-'+final['g3_label']

#download the file with the booleans
final.to_csv(data_dir+'finalwithbooleans.csv')

# %%
#look at the grouped guilties
final[['g1', 'g2', 'g3']] = final[['g1', 'g2', 'g3']].fillna('')
final[['g1', 'g2', 'g3']] = final[['g1', 'g2', 'g3']].replace('na',' ')
final['g']=final['g1']+'-'+final['g2']+'-'+final['g3']
final[['g1_label', 'g2_label', 'g3_label']] = final[['g1_label', 'g2_label', 'g3_label']].fillna('')
final['g_label']=final['g1_label']+'-'+final['g2_label']+'-'+final['g3_label']

#look at most popular 
grouped_final = final.groupby('g_label').size().reset_index(name='count')

#download the file with the booleans
final.to_csv('downloads/haltdata.csv')

# %%
#sum up to see a count of trues for each guilty
true_counts = final.loc[:, 'UNHYGIENIC ACT':'FALSE ALARM'].sum()

# Plot the histogram of true_counts
plt.hist(true_counts, bins=100)

# Set the title and axis labels
plt.title('Histogram of True Values in Boolean Columns')
plt.xlabel('Count')
plt.ylabel('Frequency')

plt.show()

# %%
true_counts50 = true_counts[true_counts >= 50]
true_counts50=true_counts50.sort_values()

# Create a horizontal bar chart of the filtered true counts
plt.barh(true_counts50.index, true_counts50.values)

# Set the title and axis labels
plt.title('Number of True Values in Boolean Columns (Counts >= 50)')
plt.ylabel('Boolean Column')
plt.xlabel('Count')

plt.tight_layout()

# Display the chart
plt.show()

# %%
#plot a histogram of the grouped guilties
plt.hist(grouped_final['count'])

# Add title and axis labels
plt.title('Histogram: Grouped Guilties')
plt.xlabel('Count')
plt.ylabel('Frequency')

# Display the histogram
plt.show()

# %%
# Get the top 10 groups with the highest counts
top_counts = grouped_final.sort_values('count', ascending=False).head(10)

# Create a horizontal bar chart of the top counts
plt.barh(top_counts['g_label'], top_counts['count'])

# Set the title and axis labels
plt.title('Top 10 Groups with Highest Counts')
plt.xlabel('Count')

plt.tight_layout()

# Display the chart
plt.show()

# %%
# Group the DataFrame by the "facility" column and count the number of occurrences of each facility
counts = final.groupby("facility").size()

# Plot the histogram of true_counts
plt.hist(counts, bins=100)

# Set the title and axis labels
plt.title('Histogram of Facility Counts')
plt.xlabel('Count')
plt.ylabel('Frequency')

plt.show()

# %%
#look at facilities with the most records

mostrecords=final.groupby(['facility']).size().reset_index()
mostrecords.columns=['facility','numrecords']
mostrecords=mostrecords.sort_values(['numrecords'],ascending=False).head(10)

plt.barh(mostrecords['facility'], mostrecords['numrecords'])

# Set the title and axis labels
plt.title('Facilities with the Most Records')
plt.xlabel('Count')

plt.tight_layout()

# Display the chart
plt.show()

# %%
#look at facilities with the most days

incar=final.groupby(['facility','date']).size().reset_index()
incar2=incar.groupby(['facility']).size().reset_index()
incar2.columns=['facility','numdays']
incar2=incar2.sort_values(['numdays'],ascending=False).head(10)

plt.barh(incar2['facility'], incar2['numdays'])

# Set the title and axis labels
plt.title('Facilities with the Most Incident Days')
plt.xlabel('Count')

plt.tight_layout()

# Display the chart
plt.show()

# %%
sametimefacilitydate=final.groupby(['facility','date','time','g_label'])['g1'].size().reset_index()
sametimefacilitydate= sametimefacilitydate.sort_values('g1', ascending=False)
sametimefacilitydate.head(10)
# Out:
#        facility       date  time  \
# 5654    upstate 2022-04-19  1107
# 5651    upstate 2022-04-19  1105
# 1872  coxsackie 2022-08-02  2000
# 2177     elmira 2022-10-01   820
# 2899   franklin 2023-01-05   530
# 618      auburn 2022-08-10   743
# 568      auburn 2022-07-01  2130
# 160      attica 2022-05-01  2055
# 2082     elmira 2022-06-04  1522
# 2141     elmira 2022-08-08  1100
#
#                                                 g_label  g1
# 5654            DEMONSTRATION-DIRECT ORDER-INTERFERENCE  16
# 5651            DEMONSTRATION-DIRECT ORDER-INTERFERENCE  11
# 1872    DEMONSTRATION - DIRECT ORDER - UNAUTH ASSMEBLY    9
# 2177         FIGHTING - VIOLENT CONDUCT - DIRECT ORDER    9
# 2899               THREATS - BRIBERY/EXTORTION - GANGS    9
# 618          THREATS - VIOLENT CONDUCT - DEMONSTRATION    8
# 568        DEMONSTRATION - DIRECT ORDER - INTERFERENCE    8
# 160          FIGHTING - VIOLENT CONDUCT - DIRECT ORDER    8
# 2082         FIGHTING - VIOLENT CONDUCT - DIRECT ORDER    8
# 2141   ASSAULT ON INCAR INDIV - FIGHTING - VIOLENT C...   8

# %%
final['orig_shu_days']=final['orig_shu_days'].astype(float)
shu=final['orig_shu_days']
# Plot the histogram of true_counts
plt.hist(shu, bins=10)

# Set the title and axis labels
plt.title('Histogram: Original SHU Days')
plt.xlabel('Number of Days')
plt.ylabel('Frequency')

plt.show()

# %%
#look at top shu days

final['orig_shu_days']=final['orig_shu_days'].astype('float')
final[['facility','date','time','orig_shu_days','tot_infractions','tot_g_infractions']].sort_values(['orig_shu_days'],ascending=False).head(20)
# Out:
#           facility       date  time  orig_shu_days  tot_infractions  \
# 1064  great meadow 2022-12-15  1300         1825.0                6
# 1700        auburn 2022-08-10   743         1441.0                8
# 4731       wyoming 2022-07-24  1900         1085.0                4
# 1434     coxsackie 2022-08-03  1420          900.0                4
# 5402        auburn 2022-05-16  1546          739.0               10
# 7431       clinton 2022-04-27  1550          732.0                2
# 7213       clinton 2022-04-19  2035          730.0                7
# 732   great meadow 2022-12-04  1115          730.0                5
# 1747       clinton 2022-08-11  2052          730.0                2
# 2454      sullivan 2023-01-12  1355          730.0                3
# 5990        greene 2022-11-06  1418          730.0                3
# 6607        greene 2022-04-01  1930          730.0                3
# 335        upstate 2022-09-12   715          730.0                6
# 4810       orleans 2022-05-01   835          730.0                6
# 1698        auburn 2022-08-10   743          730.0                8
# 1335     coxsackie 2022-08-01  1035          730.0                2
# 7310  cape vincent 2022-04-22  1730          730.0                6
# 5887     sing sing 2022-11-02  1455          730.0                6
# 3783       upstate 2022-06-11  1205          730.0                3
# 2620        elmira 2023-01-19  1345          730.0                4
#
#       tot_g_infractions
# 1064                5.0
# 1700                7.0
# 4731                4.0
# 1434                4.0
# 5402               10.0
# 7431                2.0
# 7213                6.0
# 732                 4.0
# 1747                2.0
# 2454                3.0
# 5990                3.0
# 6607                2.0
# 335                 5.0
# 4810                6.0
# 1698                6.0
# 1335                2.0
# 7310                4.0
# 5887                5.0
# 3783                3.0
# 2620                4.0
